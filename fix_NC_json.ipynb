# %%
from gerrychain import Graph

# %%
graph = Graph.from_json("/Users/gabe/Downloads/NC_full_vote_vtd.json")

# %%
graph
# Out:
# <Graph [2666 nodes, 7529 edges]>

# %%
for key in graph.nodes[0].keys():
    if "16G_Appeals_JudgeGeer" in key or "18G_Supreme_Justice1" in key or "18G_Appeals_Judge2" in key:
        print(key)
# Out:
# BuieU_16G_Appeals_JudgeGeer
# EaglesD_16G_Appeals_JudgeGeer
# MurphyR_16G_Appeals_JudgeGeer
# AnglinR_18G_Supreme_Justice1
# EarlsD_18G_Supreme_Justice1
# GriffinR_18G_Appeals_Judge2
# HampsonD_18G_Appeals_Judge2
# JacksonR_18G_Supreme_Justice1
# RayR_18G_Appeals_Judge2
# DEM_16G_Appeals_JudgeGeer
# REP_18G_Supreme_Justice1
# REP_18G_Appeals_Judge2

# %%
graph.to_json("dual_graphs/nc_vtds_0_indexed.json")

# %%
# for n in graph.nodes:
#     graph.nodes[n]["DEM_16G_Appeals_JudgeGeer"] = graph.nodes[n]["BuieU_16G_Appeals_JudgeGeer"] + graph.nodes[n]["EaglesD_16G_Appeals_JudgeGeer"]
#     graph.nodes[n]["REP_18G_Supreme_Justice1"] = graph.nodes[n]["JacksonR_18G_Supreme_Justice1"] + graph.nodes[n]["AnglinR_18G_Supreme_Justice1"]
#     graph.nodes[n]["REP_18G_Appeals_Judge2"] = graph.nodes[n]["GriffinR_18G_Appeals_Judge2"] + graph.nodes[n]["RayR_18G_Appeals_Judge2"]

# %%
graph.nodes[0]
# Out:
# {'boundary_node': False,
#  'area': 870814109.6644635,
#  'GEOID20': '37025008-00',
#  'CNTY_VTD': 'CABARRUS|8-00',
#  'COUNTYFP20': 25,
#  'CNTY_NAME': 'CABARRUS',
#  'CNTY_FIPS': 37025,
#  'VTDST20': '008-00',
#  'TOTPOP': 5318,
#  'HISP': 141,
#  'NH_WHITE': 4802,
#  'NH_BLACK': 197,
#  'NH_AMIN': 111,
#  'NH_ASIAN': 22,
#  'NH_NHPI': 0,
#  'NH_OTHER': 33,
#  'BALANCE': 12,
#  'BLK_ALONE': 168,
#  'BLK_COMBO': 51,
#  'VAP': 4227,
#  'HVAP': 90,
#  'WVAP': 3888,
#  'BVAP': 136,
#  'AMINVAP': 77,
#  'ASIANVAP': 9,
#  'NHPIVAP': 0,
#  'OTHERVAP': 19,
#  'BALANCEVAP': 8,
#  'BLK_VALONE': 129,
#  'BLK_VCOMBO': 17,
#  'CVAP19': 4562.385749526909,
#  'HCVAP19': 40.0,
#  'WCVAP19': 4383.438503962017,
#  'NHPICVAP19': 0.0,
#  'BCVAP19': 117.04248366013071,
#  'AMINCVAP19': 0.0,
#  'ASNCVAP19': 21.904761904761905,
#  'BALCVAP19': 0.0,
#  'CVAP14': 4071.035970669977,
#  'HCVAP14': 13.142857142857142,
#  'WCVAP14': 3788.5353551415183,
#  'NHPICVAP14': 0.0,
#  'BCVAP14': 211.8577583856013,
# ...
