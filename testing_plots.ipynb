# %%
from plotting_class import *
import numpy as np
import pandas as pd
import random
import gzip
import os

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%time
# senate = PlotFactory("Michigan", "state_senate", 0.02, 100000, "county_aware")
# congress = PlotFactory("Michigan", "congress", 0.01, 100000, "county_aware")
factory = PlotFactory("Michigan", "state_house")
# Out:
# CPU times: user 1min 27s, sys: 7.37 s, total: 1min 34s
# Wall time: 1min 35s

# %%
factory.plot("seats", election="PRES16", kinds=["ensemble", "proposed"])

# %%
factory.plot("seats", kinds=["ensemble", "proposed"])

# %%
factory.plot("BVAP", kinds=["ensemble", "proposed"])

# %%
congress.ensemble_metrics
# Out:
# {'TOTPOP': {'name': 'TOTPOP', 'type': 'district_level'},
#  'WHITE': {'name': 'WPOP', 'type': 'district_level'},
#  'BLACK': {'name': 'BPOP', 'type': 'district_level'},
#  'AMIN': {'name': 'AMINPOP', 'type': 'district_level'},
#  'ASIAN': {'name': 'ASIANPOP', 'type': 'district_level'},
#  'NHPI': {'name': 'NHPIPOP', 'type': 'district_level'},
#  'OTHER': {'name': 'OTHERPOP', 'type': 'district_level'},
#  '2MORE': {'name': '2MOREPOP', 'type': 'district_level'},
#  'HISP': {'name': 'HPOP', 'type': 'district_level'},
#  'VAP': {'name': 'VAP', 'type': 'district_level'},
#  'WVAP': {'name': 'WVAP', 'type': 'district_level'},
#  'BVAP': {'name': 'BVAP', 'type': 'district_level'},
#  'AMINVAP': {'name': 'AMINVAP', 'type': 'district_level'},
#  'ASIANVAP': {'name': 'ASIANVAP', 'type': 'district_level'},
#  'NHPIVAP': {'name': 'NHPIVAP', 'type': 'district_level'},
#  'OTHERVAP': {'name': 'OTHERVAP', 'type': 'district_level'},
#  '2MOREVAP': {'name': '2MOREVAP', 'type': 'district_level'},
#  'HVAP': {'name': 'HVAP', 'type': 'district_level'},
#  'num_cut_edges': {'name': 'Cut Edges', 'type': 'plan_wide'},
#  'num_county_pieces': {'name': 'County Pieces', 'type': 'plan_wide'},
#  'num_split_counties': {'name': 'Split Counties', 'type': 'plan_wide'},
#  'seats': {'name': 'Seats Won', 'type': 'election_level'},
#  'efficiency_gap': {'name': 'Efficiency Gap', 'type': 'election_level'},
#  'mean_median': {'name': 'Mean Median', 'type': 'election_level'},
#  'partisan_bias': {'name': 'Partisan Bias', 'type': 'election_level'},
#  'eguia_county': {'name': 'Eguia Metric by County', 'type': 'election_level'},
#  'num_swing_districts': {'name': 'Swing Districts', 'type': 'plan_wide'},
#  'num_competitive_districts': {'name': 'Competitive Districts',
#   'type': 'plan_wide'},
#  'num_party_districts': {'name': 'Safe {} Districts', 'type': 'plan_wide'},
#  'num_op_party_districts': {'name': 'Safe {} Districts', 'type': 'plan_wide'},
#  'num_party_wins_by_district': {'name': '{} Wins by District',
#   'type': 'plan_wide'}}

# %%
len(congress.aggregate_score("num_split_counties", kind="proposed"))
# Out:
# 4

# %%
len(congress.aggregate_score("num_split_counties", kind="citizen"))
# Out:
# 110

# %%
len(congress.aggregate_score("num_split_counties", kind="ensemble"))
# Out:
# 100000

# %%
congress.aggregate_score("num_split_counties", kind="proposed")
# Out:
# []

# %%
congress.ensemble_metrics.keys()
# Out:
# dict_keys(['TOTPOP', 'WHITE', 'BLACK', 'AMIN', 'ASIAN', 'NHPI', 'OTHER', '2MORE', 'HISP', 'VAP', 'WVAP', 'BVAP', 'AMINVAP', 'ASIANVAP', 'NHPIVAP', 'OTHERVAP', '2MOREVAP', 'HVAP', 'num_cut_edges', 'num_county_pieces', 'num_split_counties', 'seats', 'efficiency_gap', 'mean_median', 'partisan_bias', 'eguia_county', 'num_swing_districts', 'num_competitive_districts', 'num_party_districts', 'num_op_party_districts', 'num_party_wins_by_district'])

# %%
congress.plot("seats", kinds=["ensemble", "proposed"])
# Out:
# No handles with labels found to put in legend.

# %%
congress.plot("BVAP", boxplot=False, raw=False, kinds=["citizen"])

# %%
congress.plot("seats", election="PRES16", kinds=["citizen", "ensemble"])

# %%
congress.plot("seats", election="PRES16", kinds=["ensemble", "citizen"])

# %%
senate.plot("num_cut_edges", kinds=["ensemble", "citizen", "proposed"])

# %%
senate

# %%
congress.plot("num_cut_edges", kinds=["ensemble", "citizen"])

# %%
senate.plot("seats", election="PRES16")

# %%
congress.plot("mean_median", kinds=["ensemble", "citizen"])

# %%
senate.plot("num_cut_edges", kinds=["ensemble", "citizen"])

# %%
congress.plot("seats", election="PRES16", kinds=["ensemble", "citizen"])

# %%
senate.plot("seats", election="PRES16", kinds=["ensemble", "citizen"])

# %%
congress.plot("seats", kinds=["ensemble", "citizen"])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
senate.plot("seats", kinds=["ensemble", "citizen"])

# %%
congress.aggregate_score("BVAP", kind="proposed")
# Out:
# []

# %%
senate.plot("BVAP")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/nc/1qx970qn7p17yq9cmwrq9fmw0000gn/T/ipykernel_78377/106276383.py in <module>
# ----> 1 senate.plot("BVAP")
#
# ~/Desktop/mggg/plan-evaluation/plotting_class.py in plot(self, score, election, boxplot, raw, labels, save, with_proposed, kinds)
#     427             scores = self.aggregate_score(score, kind=plan_kind)
#     428             proposed_scores = self.aggregate_score(score, kind="proposed")
# --> 429             this_ax = self.fill_ax(this_ax, score, scores, proposed_scores, plan_kind, election, boxplot, raw, labels)
#     430         plt.show()
#     431         return
#
# ~/Desktop/mggg/plan-evaluation/plotting_class.py in fill_ax(self, ax, score, scores, proposed_scores, kind, election, boxplot, raw, labels)
#     462             sorted_proposed_scores, labels = self.resort_populations(score, proposed_scores, raw, plan_type="proposed") if proposed_scores else [], []
#     463             plotting_func = getattr(self, "plot_boxplot" if boxplot else "plot_violin")
# --> 464             ax = plotting_func(ax,
#     465                                kind,
#     466                                score,
#
# ~/Desktop/mggg/plan-evaluation/plotting_class.py in plot_violin(self, ax, kind, score, scores, proposed_scores, labels)
#     215                 for j, s in enumerate(proposed_scores[i]):
#     216                     jitter = random.uniform(-1/10, 1/10) if proposed_scores[i].count(s) > 1 else 0
# --> 217                     ax.scatter(i + 1 + jitter,
#     218                                 s,
#     219                                 color=self.proposed_colors[j],
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4496         y = np.ma.ravel(y)
#    4497         if x.size != y.size:
# -> 4498             raise ValueError("x and y must be the same size")
#    4499
#    4500         if s is None:
#
# ValueError: x and y must be the same size

# %%
congress.plot("BVAP", kinds=["citizen"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/nc/1qx970qn7p17yq9cmwrq9fmw0000gn/T/ipykernel_78377/491240005.py in <module>
# ----> 1 congress.plot("BVAP", kinds=["citizen"])
#
# ~/Desktop/mggg/plan-evaluation/plotting_class.py in plot(self, score, election, boxplot, raw, labels, save, with_proposed, kinds)
#     427             scores = self.aggregate_score(score, kind=plan_kind)
#     428             proposed_scores = self.aggregate_score(score, kind="proposed")
# --> 429             this_ax = self.fill_ax(this_ax, score, scores, proposed_scores, plan_kind, election, boxplot, raw, labels)
#     430         plt.show()
#     431         return
#
# ~/Desktop/mggg/plan-evaluation/plotting_class.py in fill_ax(self, ax, score, scores, proposed_scores, kind, election, boxplot, raw, labels)
#     459                                      )
#     460         elif self.ensemble_metrics[score]["type"] == "district_level":
# --> 461             sorted_scores, labels = self.resort_populations(score, scores, raw, plan_type="ensemble")
#     462             sorted_proposed_scores, labels = self.resort_populations(score, proposed_scores, raw, plan_type="proposed") if proposed_scores else [], []
#     463             plotting_func = getattr(self, "plot_boxplot" if boxplot else "plot_violin")
#
# ~/Desktop/mggg/plan-evaluation/plotting_class.py in resort_populations(self, score, scores, raw, plan_type)
#     362                 sorted_scores = sorted([scores[d][i] for d in scores.keys()])
#     363             else:
# --> 364                 sorted_scores = sorted([scores[d][i] / totpop[d][i] for d in scores.keys()])
#     365             for j, value in enumerate(sorted_scores):
#     366                 sorted_districts[j+1].append(value)
#
# ~/Desktop/mggg/plan-evaluation/plotting_class.py in <listcomp>(.0)
#     362                 sorted_scores = sorted([scores[d][i] for d in scores.keys()])
#     363             else:
# --> 364                 sorted_scores = sorted([scores[d][i] / totpop[d][i] for d in scores.keys()])
#     365             for j, value in enumerate(sorted_scores):
#     366                 sorted_districts[j+1].append(value)
#
# KeyError: '0'
